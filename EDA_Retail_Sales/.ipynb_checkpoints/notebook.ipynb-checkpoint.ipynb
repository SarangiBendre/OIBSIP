# %% [markdown]
# # Exploratory Data Analysis on Retail Sales Data
#
# ## Objective
# To analyze retail sales data to uncover patterns, trends, and insights
# that help understand business performance and customer behavior.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\saran'

# %%
import os
os.chdir(r"C:\Users\saran\OneDrive\Documents\GitHub\SarangiBendre-profile\OIBSIP\EDA_Retail_Sales")

# %%
df = pd.read_csv("data/retail_sales.csv")
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# STEP 1: Convert Date column to datetime

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Transaction ID               int64
# Date                datetime64[ns]
# Customer ID                 object
# Gender                      object
# Age                          int64
# Product Category            object
# Quantity                     int64
# Price per Unit               int64
# Total Amount                 int64
# dtype: object

# %% [markdown]
# STEP 2: Check Age sanity

# %%
df['Age'].describe()
# Out:
# count    1000.00000
# mean       41.39200
# std        13.68143
# min        18.00000
# 25%        29.00000
# 50%        42.00000
# 75%        53.00000
# max        64.00000
# Name: Age, dtype: float64

# %% [markdown]
# STEP 3: Check Gender consistency

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %% [markdown]
# STEP 4: Check Product Categories

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %% [markdown]
# Sales by Product Category

# %%
category_sales = df.groupby('Product Category')['Total Amount'].sum()
category_sales
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(6,4))
category_sales.plot(kind='bar')
plt.title("Total Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# Gender-wise Spending

# %%
gender_sales = df.groupby('Gender')['Total Amount'].sum()
gender_sales
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(6,4))
gender_sales.plot(kind='bar')
plt.title("Total Sales by Gender")
plt.xlabel("Gender")
plt.ylabel("Total Sales")
plt.show()

# %% [markdown]
# Age distribution

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Age'], bins=10)
plt.title("Age Distribution of Customers")
plt.xlabel("Age")
plt.ylabel("Number of Customers")
plt.show()

# %% [markdown]
# ## Key Insights
#
# 1. Electronics is the highest revenue-generating product category, indicating higher-value purchases compared to other categories.
#
# 2. Female customers contribute slightly more to total sales than male customers, despite nearly equal representation in the dataset.
#
# 3. The majority of customers fall within the 25–60 age range, with peak concentration around middle-aged groups, suggesting this demographic as the primary target market.
#
# 4. The dataset is clean with no duplicate records and realistic age values, making the analysis reliable.
